# %% [markdown]
# # Formation ML Flow

# %% [markdown]
# L'objectif de cette formation est de vous apprendre à utiliser ML Flow
# MLflow est un dashboard pour expériences de Machine Learning.
# Ce tp permet pas à pas comment lancer une expérience de Machine Learning et surveiller les paramètres, métriques et resultats de votre expérience grâce à ML Flow.
#
# Nous allons mettre en place plkusieurs modèles et découvrir MLflow

# %% [markdown]
# ### import des librairies

# %%
# !pip install mlflow
# !pip install mlflow_skinny
import mlflow, math, time
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns

from sklearn import datasets
from sklearn.dummy import DummyClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
# Out:
# Collecting mlflow
#   Using cached mlflow-2.1.1-py3-none-any.whl (16.7 MB)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (2.27.1)
# Requirement already satisfied: gitpython<4,>=2.1.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (3.1.30)
# Requirement already satisfied: click<9,>=7.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (8.0.4)
# Requirement already satisfied: scikit-learn<2 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (1.1.3)
# Requirement already satisfied: pytz<2023 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (2021.3)
# Collecting waitress<3
#   Using cached waitress-2.1.2-py3-none-any.whl (57 kB)
# Requirement already satisfied: packaging<23 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (21.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (3.3.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (0.4.3)
# Collecting pyarrow<11,>=4.0.0
#   Using cached pyarrow-10.0.1-cp39-cp39-win_amd64.whl (20.3 MB)
# Requirement already satisfied: entrypoints<1 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (0.4)
# Requirement already satisfied: scipy<2 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (1.10.0)
# Collecting shap<1,>=0.40
#   Using cached shap-0.41.0-cp39-cp39-win_amd64.whl (435 kB)
# Collecting docker<7,>=4.0.0
#   Using cached docker-6.0.1-py3-none-any.whl (147 kB)
# Requirement already satisfied: Flask<3 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (2.2.2)
# Requirement already satisfied: cloudpickle<3 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (2.0.0)
# Collecting alembic<2
#   Using cached alembic-1.9.3-py3-none-any.whl (210 kB)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Accès refusé: 'C:\\Users\\utilisateur\\anaconda3\\Lib\\site-packages\\pywin32_system32\\pywintypes39.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (4.11.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (6.0)
# Requirement already satisfied: pandas<2 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (1.4.2)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (1.4.32)
# Collecting querystring-parser<2
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: matplotlib<4 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (3.5.1)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (0.17.4)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (3.19.1)
# Requirement already satisfied: numpy<2 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow) (1.21.5)
# Collecting Mako
#   Using cached Mako-1.2.4-py3-none-any.whl (78 kB)
# Requirement already satisfied: colorama in c:\users\utilisateur\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.6)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (3.2.2)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (2.1.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.16.0)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\utilisateur\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow) (0.8.9)
# Collecting pywin32>=304
#   Using cached pywin32-305-cp39-cp39-win_amd64.whl (12.2 MB)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow) (0.58.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from docker<7,>=4.0.0->mlflow) (1.26.9)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from Flask<3->mlflow) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\utilisateur\anaconda3\lib\site-packages (from Flask<3->mlflow) (2.2.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from gitpython<4,>=2.1.0->mlflow) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\utilisateur\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow) (3.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\utilisateur\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\utilisateur\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (9.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.1.0)
# Collecting slicer==0.0.7
#   Using cached slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in c:\users\utilisateur\anaconda3\lib\site-packages (from shap<1,>=0.40->mlflow) (0.55.1)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from shap<1,>=0.40->mlflow) (4.64.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\utilisateur\anaconda3\lib\site-packages (from sqlalchemy<2,>=1.4.0->mlflow) (1.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow) (5.0.0)
# Requirement already satisfied: setuptools in c:\users\utilisateur\anaconda3\lib\site-packages (from numba->shap<1,>=0.40->mlflow) (61.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\utilisateur\anaconda3\lib\site-packages (from numba->shap<1,>=0.40->mlflow) (0.38.0)
# Installing collected packages: pywin32, waitress, slicer, querystring-parser, pyarrow, Mako, docker, alembic, shap, mlflow
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 302
#     Uninstalling pywin32-302:
#       Successfully uninstalled pywin32-302
#   Rolling back uninstall of pywin32
#   Moving to c:\users\utilisateur\anaconda3\lib\site-packages\__pycache__\pythoncom.cpython-39.pyc
#    from C:\Users\utilisateur\AppData\Local\Temp\pip-uninstall-k5jqknq9\pythoncom.cpython-39.pyc
#   Moving to c:\users\utilisateur\anaconda3\lib\site-packages\adodbapi
#    from C:\Users\utilisateur\anaconda3\Lib\site-packages\~dodbapi
#   Moving to c:\users\utilisateur\anaconda3\lib\site-packages\isapi
#    from C:\Users\utilisateur\anaconda3\Lib\site-packages\~sapi
#   Moving to c:\users\utilisateur\anaconda3\lib\site-packages\pythoncom.py
#    from C:\Users\utilisateur\AppData\Local\Temp\pip-uninstall-w6xbhrde\pythoncom.py
#   Moving to c:\users\utilisateur\anaconda3\lib\site-packages\pythonwin
#    from C:\Users\utilisateur\anaconda3\Lib\site-packages\~ythonwin
#   Moving to c:\users\utilisateur\anaconda3\lib\site-packages\pywin32-302-py3.9.egg-info
#    from C:\Users\utilisateur\anaconda3\Lib\site-packages\~ywin32-302-py3.9.egg-info
#   Moving to c:\users\utilisateur\anaconda3\lib\site-packages\win32\lib\
#    from C:\Users\utilisateur\anaconda3\Lib\site-packages\win32\~ib
#   Moving to c:\users\utilisateur\anaconda3\lib\site-packages\win32com
#    from C:\Users\utilisateur\anaconda3\Lib\site-packages\~in32com
#   Moving to c:\users\utilisateur\anaconda3\lib\site-packages\win32comext
#    from C:\Users\utilisateur\anaconda3\Lib\site-packages\~in32comext
# Requirement already satisfied: mlflow_skinny in c:\users\utilisateur\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: pytz<2023 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow_skinny) (2021.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow_skinny) (0.4.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow_skinny) (8.0.4)
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow_skinny) (4.11.3)
# Requirement already satisfied: gitpython<4,>=2.1.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow_skinny) (3.1.30)
# Requirement already satisfied: packaging<23 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow_skinny) (21.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow_skinny) (6.0)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow_skinny) (3.19.1)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow_skinny) (2.27.1)
# Requirement already satisfied: cloudpickle<3 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow_skinny) (2.0.0)
# Requirement already satisfied: entrypoints<1 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow_skinny) (0.4)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in c:\users\utilisateur\anaconda3\lib\site-packages (from mlflow_skinny) (0.17.4)
# Requirement already satisfied: colorama in c:\users\utilisateur\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow_skinny) (0.4.6)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow_skinny) (2.1.0)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\utilisateur\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow_skinny) (0.8.9)
# Requirement already satisfied: six>=1.10.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow_skinny) (1.16.0)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from databricks-cli<1,>=0.8.7->mlflow_skinny) (3.2.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from gitpython<4,>=2.1.0->mlflow_skinny) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in c:\users\utilisateur\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow_skinny) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\utilisateur\anaconda3\lib\site-packages (from packaging<23->mlflow_skinny) (3.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow_skinny) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow_skinny) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow_skinny) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\utilisateur\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow_skinny) (2022.12.7)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\utilisateur\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow_skinny) (5.0.0)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\utilisateur\anaconda3\lib\site-packages)

# %% [markdown]
# # 1. Ouverture et visualisation du dataset Iris

# %%
# permet d'avoir accès au dataset une fois qu'il sera chargé
dataset_columns = ['sepal length', 'sepal width', 'petal length', 'petal width']

try: 
    dataset = pd.read_csv('iris.csv')
except FileNotFoundError:
    iris_data = datasets.load_iris(as_frame=True)
    dataset = iris_data.get('data')
    dataset.columns = columns=dataset_columns
    dataset["target"] = iris_data.get('target')
    dataset['target'] = dataset['target'].replace(dataset['target'].unique().tolist(), iris_data.get('target_names'))
    dataset.to_csv('iris.csv', index=False)
dataset.head()
# Out:
#    sepal length  sepal width  petal length  petal width  target
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# affichons en une simple ligne de code les caractéristiques des colonnes numériques

#Code ici
dataset.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Verifions que les données soient bien homogènes (2 méthodes)

# Code ici
if len(set(dataset.dtypes)) == 1:
    print('Les données sont bien homogènes')
else:
    print('Les données ne sont pas homogènes')
# Out:
# Les données ne sont pas homogènes

# %% [markdown]
# Affichons maintenant le nuage de points de chaque paire de caractéristiques. Sur la diagonale, on retrouve un histogramme du nombre d'échantillons selon la valeur de la caractéristique. On peut remarquer certaines structures, par exemple des groupes, dans les relations entre certaines caractéristiques.

# %%
# tout groupe confondu, affichez le nuage de point par paire de variable et en diagonale l'histogramme de la variable 
pd.plotting.scatter_matrix(dataset,figsize=(12,8))
plt.suptitle('Scatter matrix of the Iris dataset')
plt.show()

# %%
#essayons avec seaborn, et mettons une couleur par classe

#Code ici
sns.pairplot(dataset, hue='target')
plt.show()

# %% [markdown]
# On remarque des corrélations avec certaines caractéristiques

# %% [markdown]
# # 2. ML Flow : premiers pas avec un modèle aléatoire

# %% [markdown]
# Pour un premier exemple prenons une classification 'simple' : le modèle aléatoire. Ce modèle attribuera aléatoirement une classe à chaque échantillon du dataset.
#
# Séparons le dataset en deux X, nos features et Y notre class des iris

# %%
X = dataset.loc[:,dataset_columns].values
Y = dataset.target.values

# %%
#Construisons notre modèle aléatoire :
dummy = DummyClassifier(strategy="uniform")
dummy.fit(X, Y)
# Out:
# DummyClassifier(strategy='uniform')

# %% [markdown]
# Affichons ses prédictions pour les premiers échantillons :

# %%
Y_pred = dummy.predict(X)
for i in range(5):
    print(X[i], ', vraie classe : ', Y[i], ', prédiction : ', Y_pred[i])
# Out:
# [5.1 3.5 1.4 0.2] , vraie classe :  setosa , prédiction :  versicolor
# [4.9 3.  1.4 0.2] , vraie classe :  setosa , prédiction :  virginica
# [4.7 3.2 1.3 0.2] , vraie classe :  setosa , prédiction :  versicolor
# [4.6 3.1 1.5 0.2] , vraie classe :  setosa , prédiction :  virginica
# [5.  3.6 1.4 0.2] , vraie classe :  setosa , prédiction :  setosa

# %% [markdown]
# Je vous laisse imagienr la qualité du modèle sachant qu'il prédit ce qu'il apprend ...

# %% [markdown]
# C'est maintenant que MLflow rentre en jeu, enregistrons les performances du modèle
# Histoire de ne pas avoir d'erreur créons un fichier `iris.txt`

# %%
# !echo > iris.txt

# %%
with mlflow.start_run(run_name='Modele_Aleatoire'):
    mlflow.log_param('Je teste mon modèle', 'DummyClassifier')
    mlflow.log_metric('Accuracy', accuracy_score(Y, Y_pred))
    mlflow.log_artifact('iris.txt')

# %%
with mlflow.start_run(run_name='Modele_Aleatoire avec csv'):
    mlflow.log_param('Je teste mon modèle', 'DummyClassifier')
    mlflow.log_metric('Accuracy', accuracy_score(Y, Y_pred))
    mlflow.log_artifact('iris.csv')

# %% [markdown]
# ici on a remplacé le fichier vide `iris.txt` par `iris.csv`

# %% [markdown]
# Si jamais vous avez supprimé votre dossier `mlruns` relancez le notebook

# %% [markdown]
# PAUSE ! c'est là ou ça devient intéressant, vous venez de créer un nouveau dossier `mlruns`, il est nécessaire pour la suite des évènements

# %% [markdown]
# Toujours dans le dossier formation-mlflow, entrez la commande mlflow ui. Le message Serving on http://XXXXXXX:5000 devrait s'afficher. Ouvrez maintenant un navigateur web et ouvrez une fenêtre vers l'url http://localhost:5000/

# %%
# !mlflow ui
# Out:
# Traceback (most recent call last):
#   File "C:\Users\utilisateur\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\utilisateur\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\utilisateur\anaconda3\Scripts\mlflow.exe\__main__.py", line 7, in <module>
#   File "C:\Users\utilisateur\anaconda3\lib\site-packages\click\core.py", line 1128, in __call__
#     return self.main(*args, **kwargs)
#   File "C:\Users\utilisateur\anaconda3\lib\site-packages\click\core.py", line 1053, in main
#     rv = self.invoke(ctx)
#   File "C:\Users\utilisateur\anaconda3\lib\site-packages\click\core.py", line 1659, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "C:\Users\utilisateur\anaconda3\lib\site-packages\click\core.py", line 1395, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "C:\Users\utilisateur\anaconda3\lib\site-packages\click\core.py", line 754, in invoke
#     return __callback(*args, **kwargs)
#   File "C:\Users\utilisateur\anaconda3\lib\site-packages\mlflow\cli.py", line 399, in server
#     _run_server(
#   File "C:\Users\utilisateur\anaconda3\lib\site-packages\mlflow\server\__init__.py", line 161, in _run_server
#     _exec_cmd(full_command, extra_env=env_map, capture_output=False)
#   File "C:\Users\utilisateur\anaconda3\lib\site-packages\mlflow\utils\process.py", line 95, in _exec_cmd
#     process = subprocess.Popen(
#   File "C:\Users\utilisateur\anaconda3\lib\subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\utilisateur\anaconda3\lib\subprocess.py", line 1420, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# FileNotFoundError: [WinError 2] Le fichier spécifié est introuvable

# %% [markdown]
# Ca y est les resultats sont visibles sur l'interface ! discutons en un peu
#
# ML Flow permet d'enregistrer puis visualiser 4 types de choses :
#
# des paramètres : ce sont des valeurs (int, float, string, ...) qui ne varient pas au cours d'un 'run', ici `MODEL_NAME` ou encore `je teste mon modèle` est un paramètre
#
# des métriques : ce sont des valeurs numériques qui peuvent varier au cours du 'run', ici Accuracy est une métrique
#
# des fichiers : ces fichiers peuvent prendre n'importe quelle forme (png, jpeg, gif, txt, ...) et ne sont pas modifiables au cours du 'run. Ici nous avons fait une copie du fichier iris.csv et de iris.txt
#
# Toutes ces variables sont regroupées dans un même 'run', ici nommé `Modele_Aleatoire` ou `modele aleatoire avec csv`. Un 'run' correspond à une ligne du tableau. Les 'runs' peuvent être regroupés en 'experiences', ici nommée Default dans la colonne de gauche. Nous verons comment changer le nom de l'expérience par la suite

# %%
# 1. Création du 'run' ML FLow, nommé ici 'Modele_Aleatoire'
#    un run est inclus dans une expérience
with mlflow.start_run(run_name='Modele_Aleatoire'):

    # 2. Enregistrement d'un paramètre, c'est par exemple le nom de notre modèle testé, les fameux 'final1', 'final_final'
    mlflow.log_param('MODEL_NAME', 'DummyClassifier')

    # 3. Enregistrement d'une métrique, pour qu'on n'ait plus besoin de l'ecrire sur un cahier ou sur excel
    mlflow.log_metric('Accuracy', accuracy_score(Y, Y_pred))

    # 4. Enregistrement d'un fichier, c'est notre artefact, ce qui permet aussi le reproductibilité
    mlflow.log_artifact('iris.csv')

# %% [markdown]
# ## Exercice d'application

# %% [markdown]
# petal width est une variable très discriminante pour classifier

# %%
sns.histplot(dataset, x='petal width', y='target')

# %% [markdown]
# Nous allons donc essayer de coder notre propre modèle de classification selon cette spécificité et enregistrer ses performances avec ML FLow.
#
# Pour cela, commencez par coder une fonction qui :
#
# prend en entrée une liste d'échantillons
# retourne la liste des classes des échantillons
# afin de retourner la classe de façon automatisée crée un quantile à 0.33 et un à 0.66, les classes seront dans l'ordre suivant :
# - setosa, versicolor, virginica

# %%
def simple_classification_model(list_samples):
    """
    list_sample represente l'ensemble des feature
    quantile est une liste comme celle ci : [elem1, elem2] 
    """
    #Code ici
    return petal_width_class

# %% [markdown]
# Vérifions ici que notre modele fonctionne sur quelques échantillons :

# %%
Y_pred_cond = simple_classification_model(X)
for i in range(5):
    print(X[i], ', vraie classe : ', Y[i], ', prédiction : ', Y_pred_cond[i])

# %% [markdown]
# utilisons à nouveau MLflow

# %%
#Code ici

# %% [markdown]
# # 3. ML Flow : Comparaison de plusieurs modèles

# %% [markdown]
# C'est là ou MLflow devient très intéressant ! il permet de centraliser les experiences afin d'améliorer les comparaisons.
# nous allons créer plusieurs modèles très simples, pour se faire séparons notre dataset

# %%
random_seed = 1
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.20, random_state=random_seed)

# %% [markdown]
# Construisons la liste des modèles à tester :

# %%
models = []
models.append(('LogisticRegression', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LinearDiscriminantAnalysis', LinearDiscriminantAnalysis()))
models.append(('KNeighborsClassifier', KNeighborsClassifier()))
models.append(('DecisionTreeClassifier', DecisionTreeClassifier()))
models.append(('GaussianNB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))

# %% [markdown]
# Ajoutons cette fonction qui va nous permettre de tracer de jolies matrices de confusion par la suite :

# %%
def plot_confusion_matrix(cm, target_names, title, 
                          normalize=True, save_path='matrix.png'):
    import itertools
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if normalize: cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    cmap = plt.get_cmap('Blues')
    plt.figure(figsize=(5,5))
    plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(target_names))
    plt.xticks(tick_marks, target_names, rotation=45)
    plt.yticks(tick_marks, target_names)

    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'\
               .format(accuracy, misclass))
    plt.gcf().canvas.draw()
    plt.savefig(save_path)
    plt.close()

# %% [markdown]
# Nous allons maintenant entraîner nos modèles et enregistrer leurs paramètres et métriques avec ML Flow.
#
# Nous allons voir deux nouvelles choses :
#
# Comment créer une nouvelle expérience
# Comment enregistrer plusieurs paramètres ou métriques d'un seul coup

# %%
# avant cela nous allons reconstruire le dataset pour savoir le train et le test
def artifact_df(X_training, Y_training, X_valid, Y_valid):
    df_train = pd.DataFrame(X_training, columns=dataset_columns)
    df_train['target'] = Y_training
    df_train.to_csv('train_data.csv')

    df_val = pd.DataFrame(X_valid, columns=dataset_columns)
    df_val['target'] = Y_valid
    df_val.to_csv('validation_data.csv')

    return None

# %%
# 1. Création d'une nouvelle expérience
#    Tous les nouveaux runs seront enregistrés dans cette expérience
mlflow.set_experiment('Compare_models')

for name, model in models:
    print(name)

    # 2. Création et début d'un nouveau run
    with mlflow.start_run(run_name=name):

        # 3. Enregistrement de plusieurs paramètres sous forme d'un dictionnaire
        params = {}
        params['MODEL_NAME'] = name
        params['TRAIN_SIZE'] = len(X_train)
        params['TEST_SIZE'] = len(X_val)
        params['SEED'] = random_seed
        mlflow.log_params(params)

        # On note le moment du début de l'expérience pour mesurer la durée de l'entraînement
        start = time.time()

        # Entraînement du modèle
        model.fit(X_train, Y_train)

        training_time = time.time() - start

        predictions = model.predict(X_val)

        # 4. Enregistrement de plusieurs métriques sous forme d'un dictionnaire
        metrics = {}
        metrics['Accuracy'] = accuracy_score(Y_val, predictions)
        metrics['Precision'] = precision_score(Y_val, predictions, average='macro')
        metrics['Recall'] = recall_score(Y_val, predictions, average='macro')
        metrics['Training Time'] = training_time
        mlflow.log_metrics(metrics)

        # 5. Enregistrement de la matrice de confusion
        cm = confusion_matrix(Y_val, predictions)
        plot_confusion_matrix(cm, ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'],
                              'Confusion matrix '+name)
        mlflow.log_artifact('matrix.png')
        artifact_df(X_train, Y_train, X_val, Y_val)
        mlflow.log_artifact('train_data.csv')
        mlflow.log_artifact('validation_data.csv')

# %% [markdown]
# Dans la partie gauche de l'UI vous trouverez 2 experiences differentes, selectionnez `Compare_models` et pour chaque run vous aurez la matrice de confusion et le train, test associé

# %% [markdown]
# # Exercice d'application

# %% [markdown]
# utilisez la fonction qui classifie de façon conditionnelle les iris dans l'experience crée juste avant

# %%
mlflow.set_experiment('Compare_models')

with mlflow.start_run(run_name='My_Conditional_Model'):

    #Code ici

# %% [markdown]
# # 4. ML Flow : Enregistrer l'évolution d'une métrique

# %% [markdown]
# Dans cette dernière partie, nous allons voir comment enregistrer l'évolution d'une métrique au cours du temps. Pour cela, nous allons utiliser comme modèle un réseau de neurones basique : le perceptron multi-couches.
#
# Afin de calculer nos métriques au cours de l'entrainement, nous decoupons celui-ci en plusieurs epochs. A chaque epoch, le reseau de neurone s'entraîne une fois sur l'intégralité du dataset. Tout ceci est fait automatiquement dans la fonction fit par défaut de scikit learn, mais nous allons faire les choses manuellement ici, pour visualiser l'évolution des métriques au cours de l'apprentissage.

# %%
# 1. Création et début d'un nouveau run
with mlflow.start_run(run_name='Multilayer Perceptron'):

    model = MLPClassifier(max_iter=10)
    mlflow.log_param('MODEL_NAME', 'MLPClassifier')

    N_TRAIN_SAMPLES = X_train.shape[0]
    N_EPOCHS = 10
    N_BATCH = 8
    N_CLASSES = np.unique(Y_train)
    scores_train = []
    scores_test = []

    # EPOCH
    epoch = 0
    while epoch < N_EPOCHS:
        if epoch % 2 == 0 : print('Epoch: ', epoch)
        # SHUFFLING
        random_perm = np.random.permutation(X_train.shape[0])
        mini_batch_index = 0
        while True:
            # TRAIN ON MINI-BATCH
            indices = random_perm[mini_batch_index:mini_batch_index + N_BATCH]
            model.partial_fit(X_train[indices], Y_train[indices], classes=N_CLASSES)
            mini_batch_index += N_BATCH
            if mini_batch_index >= N_TRAIN_SAMPLES:
                break

        metrics = {}
        predictions = model.predict(X_val)
        metrics['Accuracy'] = accuracy_score(Y_val, predictions)
        metrics['Precision'] = precision_score(Y_val, predictions, average='macro')
        metrics['Recall'] = recall_score(Y_val, predictions, average='macro')
        metrics['Loss'] = model.loss_
        # 2. Enregistrement de plusieurs métriques pour une epoch donnée
        mlflow.log_metrics(metrics, step=epoch)
        time.sleep(3)

        epoch += 1

# %% [markdown]
# Revenez sur le tableau des runs dans le dashboard et ouvrez le run que nous venons de créer. En cliquant sur l'une des métriques, vous pourrez voir son évolution au cours de l'apprentissage du réseau de neurones.

# %% [markdown]
# # (OPTIONAL
# ) 5. Un exercice d'application des temps d'attente

# %% [markdown]
# Pour finir, je vous propose un exercice d'application sur le thème d'un parc d'attraction, qui regroupera tout ce que nous avons appris ici.
#
# Pour cela nous allons étudier les temps d'attente de 3 attractions sur 10 jours d'avril
# FYI : les données on été choquées avec une uniforme pour qu'elles ne représentent pas totalement la réalité

# %%
wait_df = pd.read_csv('wait.csv')
wait_df = wait_df.sort_values("start").reset_index()
# on enleve les 10 derniers elements de chaque groupe
result1 = wait_df.drop(wait_df.groupby('attraction').tail(10).index, axis=0)

# %%
df = wait_df.drop_duplicates()
plt.figure(figsize=(8,6))
plt.plot(df.start, df.waiting_time)
plt.title("temps d'attente sur une attraction en avril 2022")
plt.ylabel('temps (min)')
plt.xticks(df.start.values[::300], rotation=45)
plt.show()

# %% [markdown]
# Créez au moins 3 modèles de prévisions des temps d'attente pour `l'attraction_2` uniquement et sur les 30 dernières periodes du dataframe disponible
# Ajoutez au moins 3 métriques pour évaluer les performances de vos modèles
# Pour chaque métrique, évaluez là sur l'ensemble de votre prévision, mais aussi sur chacune des échéances (T1, ..., Tk) afin de tracer dans MLFlow la courbe d'évolution de cette métrique.
# Enregistrez tout cela dans MLFlow, dans une nouvelle expérience.
# conseil : persistence, lag et forecast

# %%
# AJOUTEZ VOTRE CODE ICI
